# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus: # 每則
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence: # 每字
        whole_words.append(word)
whole_words
# Out:
# ['Wow',
#  '...',
#  'Loved',
#  'this',
#  'place',
#  '.',
#  'Crust',
#  'is',
#  'not',
#  'good',
#  '.',
#  'Not',
#  'tasty',
#  'and',
#  'the',
#  'texture',
#  'was',
#  'just',
#  'nasty',
#  '.',
#  'Stopped',
#  'by',
#  'during',
#  'the',
#  'late',
#  'May',
#  'bank',
#  'holiday',
#  'off',
#  'Rick',
#  'Steve',
#  'recommendation',
#  'and',
#  'loved',
#  'it',
#  '.',
#  'The',
#  'selection',
#  'on',
#  'the',
#  'menu',
#  'was',
#  'great',
#  'and',
#  'so',
#  'were',
#  'the',
#  'prices',
#  '.',
#  'Now',
#  'I',
#  'am',
#  'getting',
#  'angry',
#  'and',
#  'I',
#  'want',
#  'my',
#  'damn',
#  'pho',
#  '.',
#  'Honeslty',
#  'it',
#  'did',
#  "n't",
#  'taste',
#  'THAT',
#  'fresh',
#  '.',
#  ')',
#  'The',
#  'potatoes',
#  'were',
#  'like',
#  'rubber',
#  'and',
#  'you',
#  'could',
#  'tell',
#  'they',
#  'had',
#  'been',
#  'made',
#  'up',
#  'ahead',
#  'of',
#  'time',
#  'being',
#  'kept',
#  'under',
#  'a',
#  'warmer',
#  '.',
#  'The',
#  'fries',
#  'were',
#  'great',
#  'too',
#  '.',
#  'A',
#  'great',
#  'touch',
#  '.',
#  'Service',
#  'was',
#  'very',
#  'prompt',
#  '.',
#  'Would',
#  'not',
#  'go',
#  'back',
#  '.',
#  'The',
#  'cashier',
#  'had',
#  'no',
#  'care',
#  'what',
#  'so',
#  'ever',
#  'on',
#  'what',
#  'I',
#  'had',
#  'to',
#  'say',
#  'it',
#  'still',
#  'ended',
#  'up',
#  'being',
#  'wayyy',
#  'overpriced',
#  '.',
#  'I',
#  'tried',
#  'the',
#  'Cape',
#  'Cod',
#  'ravoli',
#  ',',
#  'chicken',
#  ',',
#  'with',
#  'cranberry',
#  '...',
#  'mmmm',
#  '!',
#  'I',
#  'was',
#  'disgusted',
#  'because',
#  'I',
#  'was',
#  'pretty',
#  'sure',
#  'that',
#  'was',
#  'human',
#  'hair',
#  '.',
#  'I',
#  'was',
#  'shocked',
#  'because',
#  'no',
#  'signs',
#  'indicate',
#  'cash',
#  'only',
#  '.',
#  'Highly',
#  'recommended',
#  '.',
#  'Waitress',
#  'was',
#  'a',
#  'little',
#  'slow',
#  'in',
#  'service',
#  '.',
#  'This',
#  'place',
#  'is',
#  'not',
#  'worth',
#  'your',
#  'time',
#  ',',
#  'let',
#  'alone',
#  'Vegas',
#  '.',
#  'did',
#  'not',
#  'like',
#  'at',
#  'all',
#  '.',
#  'The',
#  'Burrittos',
#  'Blah',
#  '!',
#  'The',
#  'food',
#  ',',
#  'amazing',
#  '.',
#  'Service',
#  'is',
#  'also',
#  'cute',
#  '.',
#  'I',
#  'could',
#  'care',
#  'less',
#  '...',
#  'The',
#  'interior',
#  'is',
#  'just',
#  'beautiful',
#  '.',
#  'So',
#  'they',
#  'performed',
#  '.',
#  'That',
#  "'s",
#  'right',
#  '....',
#  'the',
#  'red',
#  'velvet',
#  'cake',
#  '.....',
#  'ohhh',
#  'this',
#  'stuff',
#  'is',
#  'so',
#  'good',
#  '.',
#  '-',
#  'They',
#  'never',
#  'brought',
#  'a',
#  'salad',
#  'we',
#  'asked',
#  'for',
#  '.',
#  'This',
#  'hole',
#  'in',
#  'the',
#  'wall',
#  'has',
#  'great',
#  'Mexican',
#  'street',
#  'tacos',
#  ',',
#  'and',
#  'friendly',
#  'staff',
#  '.',
#  'Took',
#  'an',
#  'hour',
#  'to',
#  'get',
#  'our',
#  'food',
#  'only',
#  '4',
#  'tables',
#  'in',
#  'restaurant',
#  'my',
#  'food',
#  'was',
#  'Luke',
#  'warm',
#  ',',
#  'Our',
#  'sever',
#  'was',
#  'running',
#  'around',
#  'like',
#  'he',
#  'was',
#  'totally',
#  'overwhelmed',
#  '.',
#  'The',
#  'worst',
#  'was',
#  'the',
#  'salmon',
#  'sashimi',
#  '.',
#  'Also',
#  'there',
#  'are',
#  'combos',
#  'like',
#  'a',
#  'burger',
#  ',',
#  'fries',
#  ',',
#  'and',
#  'beer',
#  'for',
#  '23',
#  'which',
#  'is',
#  'a',
#  'decent',
#  'deal',
#  '.',
#  'This',
#  'was',
#  'like',
#  'the',
#  'final',
#  'blow',
#  '!',
#  'I',
#  'found',
#  'this',
#  'place',
#  'by',
#  'accident',
#  'and',
#  'I',
#  'could',
#  'not',
#  'be',
#  'happier',
#  '.',
#  'seems',
#  'like',
#  'a',
#  'good',
#  'quick',
#  'place',
#  'to',
#  'grab',
#  'a',
#  'bite',
#  'of',
#  'some',
#  'familiar',
#  'pub',
#  'food',
#  ',',
#  'but',
#  'do',
#  'yourself',
#  'a',
#  'favor',
#  'and',
#  'look',
#  'elsewhere',
#  '.',
#  'Overall',
#  ',',
#  'I',
#  'like',
#  'this',
#  'place',
#  'a',
#  'lot',
#  '.',
#  'The',
#  'only',
#  'redeeming',
#  'quality',
#  'of',
#  'the',
#  'restaurant',
#  'was',
#  'that',
#  'it',
#  'was',
#  'very',
#  'inexpensive',
#  '.',
#  'Ample',
#  'portions',
#  'and',
#  'good',
#  'prices',
#  '.',
#  'Poor',
#  'service',
#  ',',
#  'the',
#  'waiter',
#  'made',
#  'me',
#  'feel',
#  'like',
#  'I',
#  'was',
#  'stupid',
#  'every',
#  'time',
#  'he',
#  'came',
#  'to',
#  'the',
#  'table',
#  '.',
#  'My',
#  'first',
#  'visit',
#  'to',
#  'Hiro',
#  'was',
#  'a',
#  'delight',
#  '!',
#  'Service',
#  'sucks',
#  '.',
#  'The',
#  'shrimp',
#  'tender',
#  'and',
#  'moist',
#  '.',
#  'There',
#  'is',
#  'not',
#  'a',
#  'deal',
#  'good',
#  'enough',
#  'that',
#  'would',
#  'drag',
#  'me',
#  'into',
#  'that',
#  'establishment',
#  'again',
#  '.',
#  'Hard',
#  'to',
#  'judge',
#  'whether',
#  'these',
#  'sides',
#  'were',
#  'good',
#  'because',
#  'we',
#  'were',
#  'grossed',
#  'out',
#  'by',
#  'the',
#  'melted',
#  'styrofoam',
#  'and',
#  'did',
#  "n't",
#  'want',
#  'to',
#  'eat',
#  'it',
#  'for',
#  'fear',
#  'of',
#  'getting',
#  'sick',
#  '.',
#  'On',
#  'a',
#  'positive',
#  'note',
#  ',',
#  'our',
#  'server',
#  'was',
#  'very',
#  'attentive',
#  'and',
#  'provided',
#  'great',
#  'service',
#  '.',
#  'Frozen',
#  'pucks',
#  'of',
#  'disgust',
#  ',',
#  'with',
#  'some',
#  'of',
#  'the',
#  'worst',
#  'people',
#  'behind',
#  'the',
#  'register',
#  '.',
#  'The',
#  'only',
#  'thing',
#  'I',
#  'did',
#  'like',
#  'was',
#  'the',
#  'prime',
#  'rib',
#  'and',
#  'dessert',
#  'section',
#  '.',
#  'It',
#  "'s",
#  'too',
#  'bad',
#  'the',
#  'food',
#  'is',
#  'so',
#  'damn',
#  'generic',
#  '.',
#  'The',
#  'burger',
#  'is',
#  'good',
#  'beef',
#  ',',
#  'cooked',
#  'just',
#  'right',
#  '.',
#  'If',
#  'you',
#  'want',
#  'a',
#  'sandwich',
#  'just',
#  'go',
#  'to',
#  'any',
#  'Firehouse',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  'My',
#  'side',
#  'Greek',
#  'salad',
#  'with',
#  'the',
#  'Greek',
#  'dressing',
#  'was',
#  'so',
#  'tasty',
#  ',',
#  'and',
#  'the',
#  'pita',
#  'and',
#  'hummus',
#  'was',
#  'very',
#  'refreshing',
#  '.',
#  'We',
#  'ordered',
#  'the',
#  'duck',
#  'rare',
#  'and',
#  'it',
#  'was',
#  'pink',
#  'and',
#  'tender',
#  'on',
#  'the',
#  'inside',
#  'with',
#  'a',
#  'nice',
#  'char',
#  'on',
#  'the',
#  'outside',
#  '.',
#  'He',
#  'came',
#  'running',
#  'after',
#  'us',
#  'when',
#  'he',
#  'realized',
#  'my',
#  'husband',
#  'had',
#  'left',
#  'his',
#  'sunglasses',
#  'on',
#  'the',
#  'table',
#  '.',
#  'Their',
#  'chow',
#  'mein',
#  'is',
#  'so',
#  'good',
#  '!',
#  'They',
#  'have',
#  'horrible',
#  'attitudes',
#  'towards',
#  'customers',
#  ',',
#  'and',
#  'talk',
#  'down',
#  'to',
#  'each',
#  'one',
#  'when',
#  'customers',
#  'do',
#  "n't",
#  'enjoy',
#  'their',
#  'food',
#  '.',
#  'The',
#  'portion',
#  'was',
#  'huge',
#  '!',
#  'Loved',
#  'it',
#  '...',
#  'friendly',
#  'servers',
#  ',',
#  'great',
#  'food',
#  ',',
#  'wonderful',
#  'and',
#  'imaginative',
#  'menu',
#  '.',
#  'The',
#  'Heart',
#  'Attack',
#  'Grill',
#  'in',
#  'downtown',
#  'Vegas',
#  'is',
#  'an',
#  'absolutely',
#  'flat-lined',
#  'excuse',
#  'for',
#  'a',
#  'restaurant',
#  '.',
#  'Not',
#  'much',
#  'seafood',
#  'and',
#  'like',
#  '5',
#  'strings',
#  'of',
#  'pasta',
#  'at',
#  'the',
#  'bottom',
#  '.',
#  'The',
#  'salad',
#  'had',
#  'just',
#  'the',
#  'right',
#  'amount',
#  'of',
#  'sauce',
#  'to',
#  'not',
#  'over',
#  'power',
#  'the',
#  'scallop',
#  ',',
#  'which',
#  'was',
#  'perfectly',
#  'cooked',
#  '.',
#  'The',
#  'ripped',
#  'banana',
#  'was',
#  'not',
#  'only',
#  'ripped',
#  ',',
#  'but',
#  'petrified',
#  'and',
#  'tasteless',
#  '.',
#  'At',
#  'least',
#  'think',
#  'to',
#  'refill',
#  'my',
#  'water',
#  'before',
#  'I',
#  'struggle',
#  'to',
#  'wave',
#  'you',
#  'over',
#  'for',
#  '10',
#  'minutes',
#  '.',
#  'This',
#  'place',
#  'receives',
#  'stars',
#  'for',
#  'their',
#  'APPETIZERS',
#  '!',
#  '!',
#  '!',
#  'The',
#  'cocktails',
#  'are',
#  'all',
#  'handmade',
#  'and',
#  'delicious',
#  '.',
#  'We',
#  "'d",
#  'definitely',
#  'go',
#  'back',
#  'here',
#  'again',
#  '.',
#  'We',
#  'are',
#  'so',
#  'glad',
#  'we',
#  'found',
#  'this',
#  'place',
#  '.',
#  'Great',
#  'food',
#  'and',
#  'service',
#  ',',
#  'huge',
#  'portions',
#  'and',
#  'they',
#  'give',
#  'a',
#  'military',
#  'discount',
#  '.',
#  'Always',
#  'a',
#  'great',
#  'time',
#  'at',
#  'Dos',
#  'Gringos',
#  '!',
#  'Update',
#  '.....',
#  'went',
#  'back',
#  'for',
#  'a',
#  'second',
#  'time',
#  'and',
#  'it',
#  'was',
#  'still',
#  'just',
#  'as',
#  'amazing',
#  'We',
#  'got',
#  'the',
#  'food',
#  'and',
#  'apparently',
#  'they',
#  'have',
#  'never',
#  'heard',
#  'of',
#  'salt',
#  'and',
#  'the',
#  'batter',
#  'on',
#  'the',
#  'fish',
#  'was',
#  'chewy',
#  '.',
#  'A',
#  'great',
#  'way',
#  'to',
#  'finish',
#  'a',
#  'great',
#  '.',
#  'The',
#  'deal',
#  'included',
#  '5',
#  'tastings',
#  'and',
#  '2',
#  'drinks',
#  ',',
#  'and',
#  'Jeff',
#  'went',
#  'above',
#  'and',
#  'beyond',
#  'what',
#  'we',
#  'expected',
#  '.',
#  '-',
#  'Really',
#  ',',
#  'really',
#  'good',
#  'rice',
#  ',',
#  'all',
#  'the',
#  'time',
#  '.',
#  'The',
#  'service',
#  'was',
#  'meh',
#  '.',
#  'It',
#  'took',
#  'over',
#  '30',
#  'min',
#  'to',
#  'get',
#  'their',
#  'milkshake',
#  ',',
#  'which',
#  'was',
#  'nothing',
#  'more',
#  'than',
#  'chocolate',
#  'milk',
#  '.',
#  'I',
#  'guess',
#  'I',
#  'should',
#  'have',
#  'known',
#  'that',
#  'this',
#  'place',
#  'would',
#  'suck',
#  ',',
#  'because',
#  'it',
#  'is',
#  'inside',
#  'of',
#  'the',
#  'Excalibur',
#  ',',
#  'but',
#  'I',
#  'did',
#  "n't",
#  'use',
#  'my',
#  'common',
#  'sense',
#  '.',
#  'The',
#  'scallop',
#  'dish',
#  'is',
#  'quite',
#  'appalling',
#  'for',
#  'value',
#  'as',
#  'well',
#  '.',
#  '2',
#  'times',
#  '-',
#  'Very',
#  'Bad',
#  'Customer',
#  'Service',
#  '!',
#  'The',
#  'sweet',
#  'potato',
#  'fries',
#  'were',
#  'very',
#  'good',
#  'and',
#  'seasoned',
#  'well',
#  '.',
#  'Today',
#  'is',
#  'the',
#  'second',
#  'time',
#  'I',
#  "'ve",
#  'been',
#  'to',
#  'their',
#  'lunch',
#  'buffet',
#  'and',
#  'it',
#  'was',
#  'pretty',
#  'good',
#  '.',
#  'There',
#  'is',
#  'so',
#  'much',
#  'good',
#  'food',
#  'in',
#  'Vegas',
#  'that',
#  'I',
#  'feel',
#  'cheated',
#  'for',
#  'wasting',
#  'an',
#  ...]

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words) # set: 刪除重複資料
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %%
whole_words
# Out:
# {'grease',
#  'awful',
#  'Which',
#  'wagyu',
#  'older',
#  'wall',
#  'putting',
#  'pasta',
#  'Left',
#  'supposed',
#  'Those',
#  'Crostini',
#  'ribeye',
#  'touch',
#  'owner',
#  'whole',
#  'tasty',
#  'poor',
#  'preparing',
#  'Honestly',
#  'Same',
#  'brick',
#  'especially',
#  'wound',
#  'exceeding',
#  'crazy',
#  'ignored',
#  'hearts',
#  'boxes',
#  'inviting',
#  'serves',
#  'peanuts',
#  'thanks',
#  'refused',
#  'healthy',
#  'Soi',
#  'teamwork',
#  'ask',
#  'Despite',
#  'smaller',
#  'This',
#  'used',
#  'such',
#  'connoisseur',
#  'Experience',
#  'atmosphere.1',
#  'eggplant',
#  'constructed',
#  'temp.I',
#  'lived',
#  'describing',
#  'Cute',
#  'gooodd',
#  'quit',
#  'My',
#  'disrespected',
#  'bother',
#  'recommend',
#  'solidify',
#  'unhealthy',
#  'someone',
#  'heads',
#  'FORWARD',
#  'wrapped',
#  'offered',
#  'fabulous',
#  'mediocre',
#  'beauty',
#  'looking',
#  'off',
#  'redeeming',
#  'To',
#  'lighting',
#  'Are',
#  'dough',
#  'menus',
#  '/hand',
#  'chickens',
#  'inspired',
#  'servers',
#  'together',
#  'them',
#  'tailored',
#  'poured',
#  'touched',
#  'Why',
#  'go',
#  'compliments',
#  'Server',
#  'Roll',
#  'Macarons',
#  'rated',
#  'Lemon',
#  'industry',
#  'Bunch',
#  'rib',
#  'decor',
#  'strange',
#  'mussels',
#  'loving',
#  'mortified',
#  'portions',
#  'stay',
#  'voted',
#  'meatloaf',
#  'bits',
#  'Eggplant',
#  'unprofessional',
#  'into',
#  'gratitude',
#  'Fridays',
#  'reasonable',
#  'rice',
#  'gas',
#  'fast',
#  'exceptional',
#  'belly',
#  'Steve',
#  'spices',
#  'IT',
#  'Buffet',
#  'though',
#  'forth',
#  'disgusting',
#  'company',
#  'positive',
#  'but',
#  'nachos',
#  'they',
#  'Reasonably',
#  'sitting',
#  'possible',
#  'town',
#  'come',
#  'Pretty',
#  'plantains',
#  'bland',
#  'lack',
#  'Food',
#  'Gave',
#  'seems',
#  'glance',
#  'atmosphere',
#  'call',
#  'stayed',
#  'customer',
#  'joy',
#  'saying',
#  'totally',
#  'wash',
#  'judge',
#  'AVOID',
#  'mention',
#  'RUDE',
#  'particular',
#  'wait',
#  'party',
#  'hopes',
#  'tip',
#  'customers',
#  'NO',
#  'humiliated',
#  'Bloody',
#  'dine',
#  'disapppointment',
#  'enjoy',
#  'Café',
#  'loved',
#  'fondue',
#  'STEP',
#  '70+',
#  'checked',
#  '90',
#  'hit',
#  'guy',
#  'today',
#  'parties',
#  'pulled',
#  'Their',
#  'that',
#  'prefer',
#  'freaking',
#  'pats',
#  'person',
#  'said',
#  'chips',
#  'businesses',
#  'pine',
#  'usual',
#  'stuffed',
#  'Mom',
#  'nutshell',
#  'unsatisfying',
#  'ways',
#  'sucks',
#  'unique',
#  'condiment',
#  'When',
#  'meats',
#  'smelled',
#  'dead',
#  'self',
#  'tolerance',
#  'Strip',
#  'above',
#  'gyros',
#  'recommending',
#  'Dessert',
#  'eyes',
#  'sandwiches',
#  'Casino',
#  'delicioso',
#  'I',
#  'Boy',
#  'set',
#  'staff',
#  'Waited',
#  'walls',
#  'blown',
#  'dispenser',
#  'dusted',
#  'ranch',
#  'over-hip',
#  'stomach',
#  'head',
#  'Awesome',
#  'delicious',
#  'neither',
#  'Main',
#  'mind',
#  'STALE',
#  'Denny',
#  'pleased',
#  'case',
#  'mistake',
#  'awkwardly',
#  'establishment',
#  'pucks',
#  'One',
#  'Once',
#  'dipping',
#  'pizzas',
#  'passed',
#  'once',
#  'reduction',
#  'cheated',
#  'fails',
#  'Breeze',
#  'famous',
#  'juice',
#  'cow',
#  'brownish',
#  'yet',
#  'minutes',
#  'mean',
#  'inflate',
#  'Ryan',
#  'Gourmet',
#  'drinks',
#  '10',
#  'soggy',
#  'sucker',
#  'grilled',
#  'shrimp',
#  'pancake',
#  'postinos',
#  'Highly',
#  'bars',
#  'uploaded',
#  'disappointed',
#  'eel',
#  'Rick',
#  'extremely',
#  'Nicest',
#  'mmmm',
#  'Restaurant',
#  'recently',
#  'plate',
#  'between',
#  'in',
#  'powdered',
#  'likes',
#  'time',
#  'descriptions',
#  'seemed',
#  'including',
#  'suffers',
#  'live',
#  'angry',
#  'boiled',
#  'opinion',
#  'crowd',
#  'giving',
#  'colder',
#  'scallop',
#  'great',
#  'else',
#  'decent',
#  'non-customer',
#  'Hut',
#  'modern',
#  'places',
#  'moz',
#  '&',
#  'sharply',
#  'rather',
#  'coziness',
#  'IN',
#  'in-house',
#  'garden',
#  'saving',
#  'Join',
#  's',
#  'recall',
#  'Blah',
#  'winner',
#  'little',
#  'course',
#  'pastas',
#  'devine',
#  'bathroom',
#  'sashimi',
#  'sucked',
#  'brunch',
#  'biscuit',
#  'Hawaiian',
#  'us',
#  'must-stop',
#  'room',
#  'those',
#  'review',
#  'class',
#  'Albondigas',
#  'rudely',
#  'gross',
#  '7',
#  'proclaimed',
#  'handed',
#  'Heart',
#  'disgraceful',
#  'Really',
#  'hella',
#  'ambiance',
#  'received',
#  'flavor',
#  'spot',
#  '12',
#  'Host',
#  'trippy',
#  'quantity',
#  'on',
#  'Jenni',
#  'gloves.Everything',
#  'EXPERIENCE',
#  'wontons',
#  'Hunan',
#  'allergy',
#  'readers',
#  'Bachi',
#  'he',
#  'plethora',
#  'tell',
#  'THAT',
#  'Pita',
#  'climbing',
#  '.',
#  'puree',
#  'curry',
#  'peas',
#  'oh',
#  'sorely',
#  'fry',
#  'plastic',
#  'seal',
#  'brisket',
#  'smoke',
#  '30',
#  'Carly',
#  'his',
#  'dining',
#  'customize',
#  "'ll",
#  'now',
#  'cramming',
#  'Filet',
#  'Strike',
#  'bunch',
#  'somethat',
#  'officially',
#  'pink',
#  'High-quality',
#  'seasonal',
#  'hip',
#  'nicest',
#  'Things',
#  'edible',
#  'selection',
#  'takeout',
#  'judging',
#  'bellies',
#  "n't",
#  'looked',
#  'Stars',
#  'parents',
#  'count',
#  'Indian',
#  'no',
#  'Needless',
#  'croutons',
#  'andddd',
#  'combination',
#  'being',
#  'meat',
#  'club',
#  'Firehouse',
#  'bacon',
#  'mile',
#  'style',
#  'Luke',
#  'ok',
#  'As',
#  'bought',
#  'pancakes',
#  'accountant',
#  'prices',
#  'Tucson',
#  'A',
#  'know',
#  'charming',
#  'occasions',
#  'flavors',
#  'should',
#  'HAPPENED',
#  'tots',
#  'concern',
#  'opportunity',
#  'T.',
#  'sub-par',
#  'excellent',
#  'flat-lined',
#  'Sooooo',
#  'unless',
#  'terrible',
#  'Seat',
#  'wings',
#  'beans',
#  'dressing',
#  'concept',
#  'serivce',
#  'GO',
#  'do',
#  'chip',
#  'buying',
#  'fare',
#  'crêpe',
#  'Chicken',
#  'server',
#  'cheeseburger',
#  'saffron',
#  'Spend',
#  'bodes',
#  'outrageously',
#  'dirty',
#  'just',
#  'Steiners',
#  'bakery',
#  'Anyways',
#  'away',
#  'greedy',
#  'holiday',
#  'salty',
#  'lacked',
#  'more',
#  'email',
#  'Burger',
#  'kept',
#  'before',
#  'wrap',
#  'sides',
#  'huevos',
#  'sense',
#  'shower',
#  'FREEZING',
#  'accomodate',
#  'next',
#  'overcooked',
#  'provided',
#  'back',
#  'crust',
#  'topic',
#  'setting',
#  'suggestions',
#  'lawyers',
#  'excuse',
#  'outside',
#  'beautifully',
#  'beateous',
#  'Pizza',
#  'surprise',
#  'Only',
#  'gristle',
#  'mojitos',
#  'AYCE',
#  'known',
#  'is',
#  'one',
#  'want',
#  'enjoyable',
#  'WAY',
#  'gave',
#  'tribute',
#  'petty',
#  'tastings',
#  'idea',
#  'seasoning',
#  'Ample',
#  'block',
#  'Kind',
#  'attached',
#  'hilarious',
#  'downtown',
#  'myself',
#  'several',
#  'register',
#  'Nothing',
#  'amount',
#  'Disappointed',
#  'since',
#  'without',
#  'forgetting',
#  'Eclectic',
#  'deserves',
#  'batch',
#  'located',
#  'SCREAMS',
#  'meh',
#  'BETTER',
#  'like',
#  'peach',
#  'by',
#  'cart',
#  'forever',
#  '6',
#  'fair',
#  'surprised',
#  'two',
#  'glad',
#  'cream',
#  'Chipotle',
#  'old',
#  'besides',
#  'instantly',
#  'with',
#  'expectations',
#  'bread',
#  'Love',
#  'joke',
#  'grandmother',
#  'sad',
#  'salad',
#  'sliced',
#  '15',
#  '2007',
#  'delight',
#  'folks',
#  'ordering',
#  'paid',
#  'vain',
#  'completely',
#  'desired',
#  'affordable',
#  'driest',
#  'Mirage',
#  'Paying',
#  'send',
#  'fucking',
#  'Edinburgh',
#  'dirt',
#  'these',
#  'legit',
#  'missed',
#  'discount',
#  'pretty',
#  'vinaigrette',
#  'Greek',
#  'Eew',
#  'nothing',
#  'arrives',
#  'prime',
#  'Unfortunately',
#  'mains',
#  'things',
#  'privileged',
#  'funny',
#  'remember',
#  'Wo',
#  'neighborhood',
#  'Subway',
#  'degree',
#  'WASTE',
#  'hoping',
#  'cook',
#  'dont',
#  'highly',
#  'BEST',
#  'Brushfire',
#  'fried',
#  'three',
#  'Plater',
#  'gluten',
#  'Our',
#  'read',
#  'yay',
#  'pricey',
#  'rolled',
#  'really',
#  'year',
#  'hits',
#  '11.99',
#  'fun',
#  'LOVED',
#  'plus',
#  'toro',
#  'ice',
#  'soooooo',
#  'TOTAL',
#  'brings',
#  'Mediterranean',
#  'business',
#  'thin',
#  'strawberry',
#  'apparently',
#  'a',
#  'authentic',
#  'nigiri',
#  'wrong',
#  'Yeah',
#  'quick',
#  'Cod',
#  'needed',
#  'fan',
#  'lacking',
#  'enthusiastic',
#  'combo',
#  'final',
#  'honest',
#  'ten',
#  'APPETIZERS',
#  'liking',
#  'immediately',
#  'Smashburger',
#  'unfortunately',
#  'OWNERS',
#  'worst',
#  'Sat',
#  'dates',
#  'weekend',
#  'figured',
#  'bottom',
#  'help',
#  'Sorry',
#  'WILL',
#  'special',
#  'Cartel',
#  'original',
#  'despicable',
#  'containers',
#  'many',
#  '40min',
#  'boot',
#  'disgrace',
#  'new',
#  'fries',
#  'waited',
#  'rinse',
#  'summarize',
#  'nut',
#  'rich',
#  'Bellagio',
#  'thinking',
#  'star',
#  'awkward',
#  'never',
#  'people',
#  'couple',
#  'awesome',
#  'bloodiest',
#  'decision',
#  'smells',
#  'Bay',
#  'crab',
#  'dog',
#  'pub',
#  'milk',
#  'as',
#  'expected',
#  'inside',
#  'Ordered',
#  'Up',
#  'loudly',
#  'extraordinary',
#  'rarely',
#  'atrocious',
#  'Omelets',
#  'hole',
#  'greasy',
#  'stupid',
#  'left',
#  'regular',
#  'godfathers',
#  'insanely',
#  'instead',
#  'EVER',
#  'undercooked',
#  'power',
#  'Mellow',
#  'margaritas',
#  'free',
#  '...',
#  'full',
#  'poorly',
#  'have',
#  'mayo',
#  'Customer',
#  "'s",
#  'Gordon',
#  'Burrittos',
#  'ALL',
#  'deuchebaggery',
#  'truly',
#  'Vegetarian',
#  'potato',
#  'guess',
#  'pleasant',
#  'night',
#  'tiny',
#  'hospitality',
#  'flavorful',
#  'yummy',
#  'perpared',
#  'crisp',
#  'attack',
#  'dinner',
#  'big',
#  'Buldogis',
#  'BACK',
#  'offers',
#  'underwhelming',
#  'human',
#  'beautiful',
#  'WHAT',
#  '?',
#  'literally',
#  'beyond',
#  'PERFECT',
#  'lost',
#  'ohhh',
#  'dried',
#  'golden-crispy',
#  'point',
#  'stepped',
#  'held',
#  '3',
#  'its',
#  'light',
#  'Perfect',
#  'Con',
#  'get',
#  'HANDS',
#  'Mmmm',
#  'Worse',
#  'vegan/veggie',
#  'Tonight',
#  'salads',
#  'promise',
#  'WAAAAAAyyyyyyyyyy',
#  'non-fancy',
#  'First',
#  'arrived',
#  'rave',
#  'fellow',
#  'donut',
#  '1.5lb',
#  'treated',
#  'shops',
#  'flat',
#  'suggest',
#  'tough',
#  'or',
#  'Vegas',
#  'bus',
#  'meals',
#  '.....',
#  'Total',
#  'none',
#  'It',
#  'accommodations',
#  'Toast',
#  '2',
#  'peanut',
#  'picture',
#  'rate',
#  'Although',
#  'Plus',
#  'Noca',
#  'reviews',
#  'it',
#  'Wonderful',
#  'almost',
#  'boy',
#  'Mushroom',
#  'traditional',
#  'options',
#  'callings',
#  'breaks',
#  'difference',
#  'ridiculous',
#  'Area',
#  'dude',
#  'man',
#  'flop',
#  'coming',
#  'upgrading',
#  'sangria',
#  '1',
#  'summary',
#  'heart',
#  'feel',
#  'average',
#  'yum',
#  'shoots',
#  'closed',
#  'hurry',
#  'app',
#  'every',
#  'banana',
#  'duck',
#  'right',
#  'soooo',
#  'box',
#  'refrained',
#  '$',
#  'delightful',
#  'lover',
#  'smoothies',
#  'hard',
#  'still',
#  'char',
#  'decided',
#  'guys',
#  'am',
#  'flavored',
#  'Always',
#  'eat',
#  'stood',
#  'profound',
#  'evening',
#  'gratuity',
#  'occasional',
#  'turn',
#  'overhaul',
#  'certainly',
#  'ravoli',
#  'changing',
#  'For',
#  'tragedy',
#  'also',
#  'Friend',
#  'name',
#  'chains',
#  'dollars',
#  'ordered',
#  'greeted',
#  'rushed',
#  'Chinese',
#  'dreamed',
#  'door',
#  'sore',
#  'later',
#  'hardly',
#  'below',
#  'correct',
#  'companions',
#  'hereas',
#  'will',
#  'bug',
#  'Long',
#  'area',
#  'sever',
#  'NONE',
#  'Ironman',
#  'refill',
#  'MUST',
#  'All',
#  'luck',
#  'shocked',
#  'raspberry',
#  'job',
#  'how',
#  'Mango',
#  'elegantly',
#  'yukon',
#  'somewhat',
#  'buffets',
#  'yourself',
#  'Now',
#  'Dos',
#  ')',
#  'cakes',
#  'dessert',
#  'vodka',
#  'professional',
#  'honor',
#  'madhouse',
#  'strip',
#  'table',
#  'patty',
#  'further',
#  'silently',
#  'years',
#  'done',
#  'finally',
#  'But',
#  'hot',
#  'salmon',
#  'complete',
#  'satifying',
#  'performed',
#  'everyone',
#  'space',
#  'waiting',
#  'dime',
#  'poisoning',
#  'bathrooms',
#  'cover',
#  'for',
#  'etc',
#  'talking',
#  'waiter',
#  'first',
#  'vegetarian',
#  'wines',
#  'lighter',
#  'fact',
#  'watch',
#  'sexy',
#  'others',
#  'item',
#  'personally',
#  'fuzzy',
#  'editing',
#  'disagree',
#  'and',
#  'Large',
#  'doubt',
#  'Voodoo',
#  'venturing',
#  'Best',
#  'tepid',
#  'use',
#  'cool',
#  'shoe',
#  'acknowledged',
#  'provides',
#  'Be',
#  'section',
#  '8',
#  'handmade',
#  'Oh',
#  'needs',
#  "ya'all",
#  'bad',
#  'drinking',
#  'summer',
#  'may',
#  'largely',
#  'exactly',
#  'receives',
#  'week',
#  'wanted',
#  'middle',
#  'Then',
#  'cause',
#  'five',
#  'long',
#  'cashew',
#  'obviously',
#  'otherwise',
#  'helpful',
#  'typical',
#  'wish',
#  'incredibly',
#  'anyone',
#  'times',
#  'BITCHES',
#  'place',
#  'The',
#  'boyfriend',
#  'wow',
#  'bill',
#  ...}

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n += 1

# %%
word_index
# Out:
# {'grease': 0,
#  'awful': 1,
#  'Which': 2,
#  'wagyu': 3,
#  'older': 4,
#  'wall': 5,
#  'putting': 6,
#  'pasta': 7,
#  'Left': 8,
#  'supposed': 9,
#  'Those': 10,
#  'Crostini': 11,
#  'ribeye': 12,
#  'touch': 13,
#  'owner': 14,
#  'whole': 15,
#  'tasty': 16,
#  'poor': 17,
#  'preparing': 18,
#  'Honestly': 19,
#  'Same': 20,
#  'brick': 21,
#  'especially': 22,
#  'wound': 23,
#  'exceeding': 24,
#  'crazy': 25,
#  'ignored': 26,
#  'hearts': 27,
#  'boxes': 28,
#  'inviting': 29,
#  'serves': 30,
#  'peanuts': 31,
#  'thanks': 32,
#  'refused': 33,
#  'healthy': 34,
#  'Soi': 35,
#  'teamwork': 36,
#  'ask': 37,
#  'Despite': 38,
#  'smaller': 39,
#  'This': 40,
#  'used': 41,
#  'such': 42,
#  'connoisseur': 43,
#  'Experience': 44,
#  'atmosphere.1': 45,
#  'eggplant': 46,
#  'constructed': 47,
#  'temp.I': 48,
#  'lived': 49,
#  'describing': 50,
#  'Cute': 51,
#  'gooodd': 52,
#  'quit': 53,
#  'My': 54,
#  'disrespected': 55,
#  'bother': 56,
#  'recommend': 57,
#  'solidify': 58,
#  'unhealthy': 59,
#  'someone': 60,
#  'heads': 61,
#  'FORWARD': 62,
#  'wrapped': 63,
#  'offered': 64,
#  'fabulous': 65,
#  'mediocre': 66,
#  'beauty': 67,
#  'looking': 68,
#  'off': 69,
#  'redeeming': 70,
#  'To': 71,
#  'lighting': 72,
#  'Are': 73,
#  'dough': 74,
#  'menus': 75,
#  '/hand': 76,
#  'chickens': 77,
#  'inspired': 78,
#  'servers': 79,
#  'together': 80,
#  'them': 81,
#  'tailored': 82,
#  'poured': 83,
#  'touched': 84,
#  'Why': 85,
#  'go': 86,
#  'compliments': 87,
#  'Server': 88,
#  'Roll': 89,
#  'Macarons': 90,
#  'rated': 91,
#  'Lemon': 92,
#  'industry': 93,
#  'Bunch': 94,
#  'rib': 95,
#  'decor': 96,
#  'strange': 97,
#  'mussels': 98,
#  'loving': 99,
#  'mortified': 100,
#  'portions': 101,
#  'stay': 102,
#  'voted': 103,
#  'meatloaf': 104,
#  'bits': 105,
#  'Eggplant': 106,
#  'unprofessional': 107,
#  'into': 108,
#  'gratitude': 109,
#  'Fridays': 110,
#  'reasonable': 111,
#  'rice': 112,
#  'gas': 113,
#  'fast': 114,
#  'exceptional': 115,
#  'belly': 116,
#  'Steve': 117,
#  'spices': 118,
#  'IT': 119,
#  'Buffet': 120,
#  'though': 121,
#  'forth': 122,
#  'disgusting': 123,
#  'company': 124,
#  'positive': 125,
#  'but': 126,
#  'nachos': 127,
#  'they': 128,
#  'Reasonably': 129,
#  'sitting': 130,
#  'possible': 131,
#  'town': 132,
#  'come': 133,
#  'Pretty': 134,
#  'plantains': 135,
#  'bland': 136,
#  'lack': 137,
#  'Food': 138,
#  'Gave': 139,
#  'seems': 140,
#  'glance': 141,
#  'atmosphere': 142,
#  'call': 143,
#  'stayed': 144,
#  'customer': 145,
#  'joy': 146,
#  'saying': 147,
#  'totally': 148,
#  'wash': 149,
#  'judge': 150,
#  'AVOID': 151,
#  'mention': 152,
#  'RUDE': 153,
#  'particular': 154,
#  'wait': 155,
#  'party': 156,
#  'hopes': 157,
#  'tip': 158,
#  'customers': 159,
#  'NO': 160,
#  'humiliated': 161,
#  'Bloody': 162,
#  'dine': 163,
#  'disapppointment': 164,
#  'enjoy': 165,
#  'Café': 166,
#  'loved': 167,
#  'fondue': 168,
#  'STEP': 169,
#  '70+': 170,
#  'checked': 171,
#  '90': 172,
#  'hit': 173,
#  'guy': 174,
#  'today': 175,
#  'parties': 176,
#  'pulled': 177,
#  'Their': 178,
#  'that': 179,
#  'prefer': 180,
#  'freaking': 181,
#  'pats': 182,
#  'person': 183,
#  'said': 184,
#  'chips': 185,
#  'businesses': 186,
#  'pine': 187,
#  'usual': 188,
#  'stuffed': 189,
#  'Mom': 190,
#  'nutshell': 191,
#  'unsatisfying': 192,
#  'ways': 193,
#  'sucks': 194,
#  'unique': 195,
#  'condiment': 196,
#  'When': 197,
#  'meats': 198,
#  'smelled': 199,
#  'dead': 200,
#  'self': 201,
#  'tolerance': 202,
#  'Strip': 203,
#  'above': 204,
#  'gyros': 205,
#  'recommending': 206,
#  'Dessert': 207,
#  'eyes': 208,
#  'sandwiches': 209,
#  'Casino': 210,
#  'delicioso': 211,
#  'I': 212,
#  'Boy': 213,
#  'set': 214,
#  'staff': 215,
#  'Waited': 216,
#  'walls': 217,
#  'blown': 218,
#  'dispenser': 219,
#  'dusted': 220,
#  'ranch': 221,
#  'over-hip': 222,
#  'stomach': 223,
#  'head': 224,
#  'Awesome': 225,
#  'delicious': 226,
#  'neither': 227,
#  'Main': 228,
#  'mind': 229,
#  'STALE': 230,
#  'Denny': 231,
#  'pleased': 232,
#  'case': 233,
#  'mistake': 234,
#  'awkwardly': 235,
#  'establishment': 236,
#  'pucks': 237,
#  'One': 238,
#  'Once': 239,
#  'dipping': 240,
#  'pizzas': 241,
#  'passed': 242,
#  'once': 243,
#  'reduction': 244,
#  'cheated': 245,
#  'fails': 246,
#  'Breeze': 247,
#  'famous': 248,
#  'juice': 249,
#  'cow': 250,
#  'brownish': 251,
#  'yet': 252,
#  'minutes': 253,
#  'mean': 254,
#  'inflate': 255,
#  'Ryan': 256,
#  'Gourmet': 257,
#  'drinks': 258,
#  '10': 259,
#  'soggy': 260,
#  'sucker': 261,
#  'grilled': 262,
#  'shrimp': 263,
#  'pancake': 264,
#  'postinos': 265,
#  'Highly': 266,
#  'bars': 267,
#  'uploaded': 268,
#  'disappointed': 269,
#  'eel': 270,
#  'Rick': 271,
#  'extremely': 272,
#  'Nicest': 273,
#  'mmmm': 274,
#  'Restaurant': 275,
#  'recently': 276,
#  'plate': 277,
#  'between': 278,
#  'in': 279,
#  'powdered': 280,
#  'likes': 281,
#  'time': 282,
#  'descriptions': 283,
#  'seemed': 284,
#  'including': 285,
#  'suffers': 286,
#  'live': 287,
#  'angry': 288,
#  'boiled': 289,
#  'opinion': 290,
#  'crowd': 291,
#  'giving': 292,
#  'colder': 293,
#  'scallop': 294,
#  'great': 295,
#  'else': 296,
#  'decent': 297,
#  'non-customer': 298,
#  'Hut': 299,
#  'modern': 300,
#  'places': 301,
#  'moz': 302,
#  '&': 303,
#  'sharply': 304,
#  'rather': 305,
#  'coziness': 306,
#  'IN': 307,
#  'in-house': 308,
#  'garden': 309,
#  'saving': 310,
#  'Join': 311,
#  's': 312,
#  'recall': 313,
#  'Blah': 314,
#  'winner': 315,
#  'little': 316,
#  'course': 317,
#  'pastas': 318,
#  'devine': 319,
#  'bathroom': 320,
#  'sashimi': 321,
#  'sucked': 322,
#  'brunch': 323,
#  'biscuit': 324,
#  'Hawaiian': 325,
#  'us': 326,
#  'must-stop': 327,
#  'room': 328,
#  'those': 329,
#  'review': 330,
#  'class': 331,
#  'Albondigas': 332,
#  'rudely': 333,
#  'gross': 334,
#  '7': 335,
#  'proclaimed': 336,
#  'handed': 337,
#  'Heart': 338,
#  'disgraceful': 339,
#  'Really': 340,
#  'hella': 341,
#  'ambiance': 342,
#  'received': 343,
#  'flavor': 344,
#  'spot': 345,
#  '12': 346,
#  'Host': 347,
#  'trippy': 348,
#  'quantity': 349,
#  'on': 350,
#  'Jenni': 351,
#  'gloves.Everything': 352,
#  'EXPERIENCE': 353,
#  'wontons': 354,
#  'Hunan': 355,
#  'allergy': 356,
#  'readers': 357,
#  'Bachi': 358,
#  'he': 359,
#  'plethora': 360,
#  'tell': 361,
#  'THAT': 362,
#  'Pita': 363,
#  'climbing': 364,
#  '.': 365,
#  'puree': 366,
#  'curry': 367,
#  'peas': 368,
#  'oh': 369,
#  'sorely': 370,
#  'fry': 371,
#  'plastic': 372,
#  'seal': 373,
#  'brisket': 374,
#  'smoke': 375,
#  '30': 376,
#  'Carly': 377,
#  'his': 378,
#  'dining': 379,
#  'customize': 380,
#  "'ll": 381,
#  'now': 382,
#  'cramming': 383,
#  'Filet': 384,
#  'Strike': 385,
#  'bunch': 386,
#  'somethat': 387,
#  'officially': 388,
#  'pink': 389,
#  'High-quality': 390,
#  'seasonal': 391,
#  'hip': 392,
#  'nicest': 393,
#  'Things': 394,
#  'edible': 395,
#  'selection': 396,
#  'takeout': 397,
#  'judging': 398,
#  'bellies': 399,
#  "n't": 400,
#  'looked': 401,
#  'Stars': 402,
#  'parents': 403,
#  'count': 404,
#  'Indian': 405,
#  'no': 406,
#  'Needless': 407,
#  'croutons': 408,
#  'andddd': 409,
#  'combination': 410,
#  'being': 411,
#  'meat': 412,
#  'club': 413,
#  'Firehouse': 414,
#  'bacon': 415,
#  'mile': 416,
#  'style': 417,
#  'Luke': 418,
#  'ok': 419,
#  'As': 420,
#  'bought': 421,
#  'pancakes': 422,
#  'accountant': 423,
#  'prices': 424,
#  'Tucson': 425,
#  'A': 426,
#  'know': 427,
#  'charming': 428,
#  'occasions': 429,
#  'flavors': 430,
#  'should': 431,
#  'HAPPENED': 432,
#  'tots': 433,
#  'concern': 434,
#  'opportunity': 435,
#  'T.': 436,
#  'sub-par': 437,
#  'excellent': 438,
#  'flat-lined': 439,
#  'Sooooo': 440,
#  'unless': 441,
#  'terrible': 442,
#  'Seat': 443,
#  'wings': 444,
#  'beans': 445,
#  'dressing': 446,
#  'concept': 447,
#  'serivce': 448,
#  'GO': 449,
#  'do': 450,
#  'chip': 451,
#  'buying': 452,
#  'fare': 453,
#  'crêpe': 454,
#  'Chicken': 455,
#  'server': 456,
#  'cheeseburger': 457,
#  'saffron': 458,
#  'Spend': 459,
#  'bodes': 460,
#  'outrageously': 461,
#  'dirty': 462,
#  'just': 463,
#  'Steiners': 464,
#  'bakery': 465,
#  'Anyways': 466,
#  'away': 467,
#  'greedy': 468,
#  'holiday': 469,
#  'salty': 470,
#  'lacked': 471,
#  'more': 472,
#  'email': 473,
#  'Burger': 474,
#  'kept': 475,
#  'before': 476,
#  'wrap': 477,
#  'sides': 478,
#  'huevos': 479,
#  'sense': 480,
#  'shower': 481,
#  'FREEZING': 482,
#  'accomodate': 483,
#  'next': 484,
#  'overcooked': 485,
#  'provided': 486,
#  'back': 487,
#  'crust': 488,
#  'topic': 489,
#  'setting': 490,
#  'suggestions': 491,
#  'lawyers': 492,
#  'excuse': 493,
#  'outside': 494,
#  'beautifully': 495,
#  'beateous': 496,
#  'Pizza': 497,
#  'surprise': 498,
#  'Only': 499,
#  'gristle': 500,
#  'mojitos': 501,
#  'AYCE': 502,
#  'known': 503,
#  'is': 504,
#  'one': 505,
#  'want': 506,
#  'enjoyable': 507,
#  'WAY': 508,
#  'gave': 509,
#  'tribute': 510,
#  'petty': 511,
#  'tastings': 512,
#  'idea': 513,
#  'seasoning': 514,
#  'Ample': 515,
#  'block': 516,
#  'Kind': 517,
#  'attached': 518,
#  'hilarious': 519,
#  'downtown': 520,
#  'myself': 521,
#  'several': 522,
#  'register': 523,
#  'Nothing': 524,
#  'amount': 525,
#  'Disappointed': 526,
#  'since': 527,
#  'without': 528,
#  'forgetting': 529,
#  'Eclectic': 530,
#  'deserves': 531,
#  'batch': 532,
#  'located': 533,
#  'SCREAMS': 534,
#  'meh': 535,
#  'BETTER': 536,
#  'like': 537,
#  'peach': 538,
#  'by': 539,
#  'cart': 540,
#  'forever': 541,
#  '6': 542,
#  'fair': 543,
#  'surprised': 544,
#  'two': 545,
#  'glad': 546,
#  'cream': 547,
#  'Chipotle': 548,
#  'old': 549,
#  'besides': 550,
#  'instantly': 551,
#  'with': 552,
#  'expectations': 553,
#  'bread': 554,
#  'Love': 555,
#  'joke': 556,
#  'grandmother': 557,
#  'sad': 558,
#  'salad': 559,
#  'sliced': 560,
#  '15': 561,
#  '2007': 562,
#  'delight': 563,
#  'folks': 564,
#  'ordering': 565,
#  'paid': 566,
#  'vain': 567,
#  'completely': 568,
#  'desired': 569,
#  'affordable': 570,
#  'driest': 571,
#  'Mirage': 572,
#  'Paying': 573,
#  'send': 574,
#  'fucking': 575,
#  'Edinburgh': 576,
#  'dirt': 577,
#  'these': 578,
#  'legit': 579,
#  'missed': 580,
#  'discount': 581,
#  'pretty': 582,
#  'vinaigrette': 583,
#  'Greek': 584,
#  'Eew': 585,
#  'nothing': 586,
#  'arrives': 587,
#  'prime': 588,
#  'Unfortunately': 589,
#  'mains': 590,
#  'things': 591,
#  'privileged': 592,
#  'funny': 593,
#  'remember': 594,
#  'Wo': 595,
#  'neighborhood': 596,
#  'Subway': 597,
#  'degree': 598,
#  'WASTE': 599,
#  'hoping': 600,
#  'cook': 601,
#  'dont': 602,
#  'highly': 603,
#  'BEST': 604,
#  'Brushfire': 605,
#  'fried': 606,
#  'three': 607,
#  'Plater': 608,
#  'gluten': 609,
#  'Our': 610,
#  'read': 611,
#  'yay': 612,
#  'pricey': 613,
#  'rolled': 614,
#  'really': 615,
#  'year': 616,
#  'hits': 617,
#  '11.99': 618,
#  'fun': 619,
#  'LOVED': 620,
#  'plus': 621,
#  'toro': 622,
#  'ice': 623,
#  'soooooo': 624,
#  'TOTAL': 625,
#  'brings': 626,
#  'Mediterranean': 627,
#  'business': 628,
#  'thin': 629,
#  'strawberry': 630,
#  'apparently': 631,
#  'a': 632,
#  'authentic': 633,
#  'nigiri': 634,
#  'wrong': 635,
#  'Yeah': 636,
#  'quick': 637,
#  'Cod': 638,
#  'needed': 639,
#  'fan': 640,
#  'lacking': 641,
#  'enthusiastic': 642,
#  'combo': 643,
#  'final': 644,
#  'honest': 645,
#  'ten': 646,
#  'APPETIZERS': 647,
#  'liking': 648,
#  'immediately': 649,
#  'Smashburger': 650,
#  'unfortunately': 651,
#  'OWNERS': 652,
#  'worst': 653,
#  'Sat': 654,
#  'dates': 655,
#  'weekend': 656,
#  'figured': 657,
#  'bottom': 658,
#  'help': 659,
#  'Sorry': 660,
#  'WILL': 661,
#  'special': 662,
#  'Cartel': 663,
#  'original': 664,
#  'despicable': 665,
#  'containers': 666,
#  'many': 667,
#  '40min': 668,
#  'boot': 669,
#  'disgrace': 670,
#  'new': 671,
#  'fries': 672,
#  'waited': 673,
#  'rinse': 674,
#  'summarize': 675,
#  'nut': 676,
#  'rich': 677,
#  'Bellagio': 678,
#  'thinking': 679,
#  'star': 680,
#  'awkward': 681,
#  'never': 682,
#  'people': 683,
#  'couple': 684,
#  'awesome': 685,
#  'bloodiest': 686,
#  'decision': 687,
#  'smells': 688,
#  'Bay': 689,
#  'crab': 690,
#  'dog': 691,
#  'pub': 692,
#  'milk': 693,
#  'as': 694,
#  'expected': 695,
#  'inside': 696,
#  'Ordered': 697,
#  'Up': 698,
#  'loudly': 699,
#  'extraordinary': 700,
#  'rarely': 701,
#  'atrocious': 702,
#  'Omelets': 703,
#  'hole': 704,
#  'greasy': 705,
#  'stupid': 706,
#  'left': 707,
#  'regular': 708,
#  'godfathers': 709,
#  'insanely': 710,
#  'instead': 711,
#  'EVER': 712,
#  'undercooked': 713,
#  'power': 714,
#  'Mellow': 715,
#  'margaritas': 716,
#  'free': 717,
#  '...': 718,
#  'full': 719,
#  'poorly': 720,
#  'have': 721,
#  'mayo': 722,
#  'Customer': 723,
#  "'s": 724,
#  'Gordon': 725,
#  'Burrittos': 726,
#  'ALL': 727,
#  'deuchebaggery': 728,
#  'truly': 729,
#  'Vegetarian': 730,
#  'potato': 731,
#  'guess': 732,
#  'pleasant': 733,
#  'night': 734,
#  'tiny': 735,
#  'hospitality': 736,
#  'flavorful': 737,
#  'yummy': 738,
#  'perpared': 739,
#  'crisp': 740,
#  'attack': 741,
#  'dinner': 742,
#  'big': 743,
#  'Buldogis': 744,
#  'BACK': 745,
#  'offers': 746,
#  'underwhelming': 747,
#  'human': 748,
#  'beautiful': 749,
#  'WHAT': 750,
#  '?': 751,
#  'literally': 752,
#  'beyond': 753,
#  'PERFECT': 754,
#  'lost': 755,
#  'ohhh': 756,
#  'dried': 757,
#  'golden-crispy': 758,
#  'point': 759,
#  'stepped': 760,
#  'held': 761,
#  '3': 762,
#  'its': 763,
#  'light': 764,
#  'Perfect': 765,
#  'Con': 766,
#  'get': 767,
#  'HANDS': 768,
#  'Mmmm': 769,
#  'Worse': 770,
#  'vegan/veggie': 771,
#  'Tonight': 772,
#  'salads': 773,
#  'promise': 774,
#  'WAAAAAAyyyyyyyyyy': 775,
#  'non-fancy': 776,
#  'First': 777,
#  'arrived': 778,
#  'rave': 779,
#  'fellow': 780,
#  'donut': 781,
#  '1.5lb': 782,
#  'treated': 783,
#  'shops': 784,
#  'flat': 785,
#  'suggest': 786,
#  'tough': 787,
#  'or': 788,
#  'Vegas': 789,
#  'bus': 790,
#  'meals': 791,
#  '.....': 792,
#  'Total': 793,
#  'none': 794,
#  'It': 795,
#  'accommodations': 796,
#  'Toast': 797,
#  '2': 798,
#  'peanut': 799,
#  'picture': 800,
#  'rate': 801,
#  'Although': 802,
#  'Plus': 803,
#  'Noca': 804,
#  'reviews': 805,
#  'it': 806,
#  'Wonderful': 807,
#  'almost': 808,
#  'boy': 809,
#  'Mushroom': 810,
#  'traditional': 811,
#  'options': 812,
#  'callings': 813,
#  'breaks': 814,
#  'difference': 815,
#  'ridiculous': 816,
#  'Area': 817,
#  'dude': 818,
#  'man': 819,
#  'flop': 820,
#  'coming': 821,
#  'upgrading': 822,
#  'sangria': 823,
#  '1': 824,
#  'summary': 825,
#  'heart': 826,
#  'feel': 827,
#  'average': 828,
#  'yum': 829,
#  'shoots': 830,
#  'closed': 831,
#  'hurry': 832,
#  'app': 833,
#  'every': 834,
#  'banana': 835,
#  'duck': 836,
#  'right': 837,
#  'soooo': 838,
#  'box': 839,
#  'refrained': 840,
#  '$': 841,
#  'delightful': 842,
#  'lover': 843,
#  'smoothies': 844,
#  'hard': 845,
#  'still': 846,
#  'char': 847,
#  'decided': 848,
#  'guys': 849,
#  'am': 850,
#  'flavored': 851,
#  'Always': 852,
#  'eat': 853,
#  'stood': 854,
#  'profound': 855,
#  'evening': 856,
#  'gratuity': 857,
#  'occasional': 858,
#  'turn': 859,
#  'overhaul': 860,
#  'certainly': 861,
#  'ravoli': 862,
#  'changing': 863,
#  'For': 864,
#  'tragedy': 865,
#  'also': 866,
#  'Friend': 867,
#  'name': 868,
#  'chains': 869,
#  'dollars': 870,
#  'ordered': 871,
#  'greeted': 872,
#  'rushed': 873,
#  'Chinese': 874,
#  'dreamed': 875,
#  'door': 876,
#  'sore': 877,
#  'later': 878,
#  'hardly': 879,
#  'below': 880,
#  'correct': 881,
#  'companions': 882,
#  'hereas': 883,
#  'will': 884,
#  'bug': 885,
#  'Long': 886,
#  'area': 887,
#  'sever': 888,
#  'NONE': 889,
#  'Ironman': 890,
#  'refill': 891,
#  'MUST': 892,
#  'All': 893,
#  'luck': 894,
#  'shocked': 895,
#  'raspberry': 896,
#  'job': 897,
#  'how': 898,
#  'Mango': 899,
#  'elegantly': 900,
#  'yukon': 901,
#  'somewhat': 902,
#  'buffets': 903,
#  'yourself': 904,
#  'Now': 905,
#  'Dos': 906,
#  ')': 907,
#  'cakes': 908,
#  'dessert': 909,
#  'vodka': 910,
#  'professional': 911,
#  'honor': 912,
#  'madhouse': 913,
#  'strip': 914,
#  'table': 915,
#  'patty': 916,
#  'further': 917,
#  'silently': 918,
#  'years': 919,
#  'done': 920,
#  'finally': 921,
#  'But': 922,
#  'hot': 923,
#  'salmon': 924,
#  'complete': 925,
#  'satifying': 926,
#  'performed': 927,
#  'everyone': 928,
#  'space': 929,
#  'waiting': 930,
#  'dime': 931,
#  'poisoning': 932,
#  'bathrooms': 933,
#  'cover': 934,
#  'for': 935,
#  'etc': 936,
#  'talking': 937,
#  'waiter': 938,
#  'first': 939,
#  'vegetarian': 940,
#  'wines': 941,
#  'lighter': 942,
#  'fact': 943,
#  'watch': 944,
#  'sexy': 945,
#  'others': 946,
#  'item': 947,
#  'personally': 948,
#  'fuzzy': 949,
#  'editing': 950,
#  'disagree': 951,
#  'and': 952,
#  'Large': 953,
#  'doubt': 954,
#  'Voodoo': 955,
#  'venturing': 956,
#  'Best': 957,
#  'tepid': 958,
#  'use': 959,
#  'cool': 960,
#  'shoe': 961,
#  'acknowledged': 962,
#  'provides': 963,
#  'Be': 964,
#  'section': 965,
#  '8': 966,
#  'handmade': 967,
#  'Oh': 968,
#  'needs': 969,
#  "ya'all": 970,
#  'bad': 971,
#  'drinking': 972,
#  'summer': 973,
#  'may': 974,
#  'largely': 975,
#  'exactly': 976,
#  'receives': 977,
#  'week': 978,
#  'wanted': 979,
#  'middle': 980,
#  'Then': 981,
#  'cause': 982,
#  'five': 983,
#  'long': 984,
#  'cashew': 985,
#  'obviously': 986,
#  'otherwise': 987,
#  'helpful': 988,
#  'typical': 989,
#  'wish': 990,
#  'incredibly': 991,
#  'anyone': 992,
#  'times': 993,
#  'BITCHES': 994,
#  'place': 995,
#  'The': 996,
#  'boyfriend': 997,
#  'wow': 998,
#  'bill': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'grease',
#  1: 'awful',
#  2: 'Which',
#  3: 'wagyu',
#  4: 'older',
#  5: 'wall',
#  6: 'putting',
#  7: 'pasta',
#  8: 'Left',
#  9: 'supposed',
#  10: 'Those',
#  11: 'Crostini',
#  12: 'ribeye',
#  13: 'touch',
#  14: 'owner',
#  15: 'whole',
#  16: 'tasty',
#  17: 'poor',
#  18: 'preparing',
#  19: 'Honestly',
#  20: 'Same',
#  21: 'brick',
#  22: 'especially',
#  23: 'wound',
#  24: 'exceeding',
#  25: 'crazy',
#  26: 'ignored',
#  27: 'hearts',
#  28: 'boxes',
#  29: 'inviting',
#  30: 'serves',
#  31: 'peanuts',
#  32: 'thanks',
#  33: 'refused',
#  34: 'healthy',
#  35: 'Soi',
#  36: 'teamwork',
#  37: 'ask',
#  38: 'Despite',
#  39: 'smaller',
#  40: 'This',
#  41: 'used',
#  42: 'such',
#  43: 'connoisseur',
#  44: 'Experience',
#  45: 'atmosphere.1',
#  46: 'eggplant',
#  47: 'constructed',
#  48: 'temp.I',
#  49: 'lived',
#  50: 'describing',
#  51: 'Cute',
#  52: 'gooodd',
#  53: 'quit',
#  54: 'My',
#  55: 'disrespected',
#  56: 'bother',
#  57: 'recommend',
#  58: 'solidify',
#  59: 'unhealthy',
#  60: 'someone',
#  61: 'heads',
#  62: 'FORWARD',
#  63: 'wrapped',
#  64: 'offered',
#  65: 'fabulous',
#  66: 'mediocre',
#  67: 'beauty',
#  68: 'looking',
#  69: 'off',
#  70: 'redeeming',
#  71: 'To',
#  72: 'lighting',
#  73: 'Are',
#  74: 'dough',
#  75: 'menus',
#  76: '/hand',
#  77: 'chickens',
#  78: 'inspired',
#  79: 'servers',
#  80: 'together',
#  81: 'them',
#  82: 'tailored',
#  83: 'poured',
#  84: 'touched',
#  85: 'Why',
#  86: 'go',
#  87: 'compliments',
#  88: 'Server',
#  89: 'Roll',
#  90: 'Macarons',
#  91: 'rated',
#  92: 'Lemon',
#  93: 'industry',
#  94: 'Bunch',
#  95: 'rib',
#  96: 'decor',
#  97: 'strange',
#  98: 'mussels',
#  99: 'loving',
#  100: 'mortified',
#  101: 'portions',
#  102: 'stay',
#  103: 'voted',
#  104: 'meatloaf',
#  105: 'bits',
#  106: 'Eggplant',
#  107: 'unprofessional',
#  108: 'into',
#  109: 'gratitude',
#  110: 'Fridays',
#  111: 'reasonable',
#  112: 'rice',
#  113: 'gas',
#  114: 'fast',
#  115: 'exceptional',
#  116: 'belly',
#  117: 'Steve',
#  118: 'spices',
#  119: 'IT',
#  120: 'Buffet',
#  121: 'though',
#  122: 'forth',
#  123: 'disgusting',
#  124: 'company',
#  125: 'positive',
#  126: 'but',
#  127: 'nachos',
#  128: 'they',
#  129: 'Reasonably',
#  130: 'sitting',
#  131: 'possible',
#  132: 'town',
#  133: 'come',
#  134: 'Pretty',
#  135: 'plantains',
#  136: 'bland',
#  137: 'lack',
#  138: 'Food',
#  139: 'Gave',
#  140: 'seems',
#  141: 'glance',
#  142: 'atmosphere',
#  143: 'call',
#  144: 'stayed',
#  145: 'customer',
#  146: 'joy',
#  147: 'saying',
#  148: 'totally',
#  149: 'wash',
#  150: 'judge',
#  151: 'AVOID',
#  152: 'mention',
#  153: 'RUDE',
#  154: 'particular',
#  155: 'wait',
#  156: 'party',
#  157: 'hopes',
#  158: 'tip',
#  159: 'customers',
#  160: 'NO',
#  161: 'humiliated',
#  162: 'Bloody',
#  163: 'dine',
#  164: 'disapppointment',
#  165: 'enjoy',
#  166: 'Café',
#  167: 'loved',
#  168: 'fondue',
#  169: 'STEP',
#  170: '70+',
#  171: 'checked',
#  172: '90',
#  173: 'hit',
#  174: 'guy',
#  175: 'today',
#  176: 'parties',
#  177: 'pulled',
#  178: 'Their',
#  179: 'that',
#  180: 'prefer',
#  181: 'freaking',
#  182: 'pats',
#  183: 'person',
#  184: 'said',
#  185: 'chips',
#  186: 'businesses',
#  187: 'pine',
#  188: 'usual',
#  189: 'stuffed',
#  190: 'Mom',
#  191: 'nutshell',
#  192: 'unsatisfying',
#  193: 'ways',
#  194: 'sucks',
#  195: 'unique',
#  196: 'condiment',
#  197: 'When',
#  198: 'meats',
#  199: 'smelled',
#  200: 'dead',
#  201: 'self',
#  202: 'tolerance',
#  203: 'Strip',
#  204: 'above',
#  205: 'gyros',
#  206: 'recommending',
#  207: 'Dessert',
#  208: 'eyes',
#  209: 'sandwiches',
#  210: 'Casino',
#  211: 'delicioso',
#  212: 'I',
#  213: 'Boy',
#  214: 'set',
#  215: 'staff',
#  216: 'Waited',
#  217: 'walls',
#  218: 'blown',
#  219: 'dispenser',
#  220: 'dusted',
#  221: 'ranch',
#  222: 'over-hip',
#  223: 'stomach',
#  224: 'head',
#  225: 'Awesome',
#  226: 'delicious',
#  227: 'neither',
#  228: 'Main',
#  229: 'mind',
#  230: 'STALE',
#  231: 'Denny',
#  232: 'pleased',
#  233: 'case',
#  234: 'mistake',
#  235: 'awkwardly',
#  236: 'establishment',
#  237: 'pucks',
#  238: 'One',
#  239: 'Once',
#  240: 'dipping',
#  241: 'pizzas',
#  242: 'passed',
#  243: 'once',
#  244: 'reduction',
#  245: 'cheated',
#  246: 'fails',
#  247: 'Breeze',
#  248: 'famous',
#  249: 'juice',
#  250: 'cow',
#  251: 'brownish',
#  252: 'yet',
#  253: 'minutes',
#  254: 'mean',
#  255: 'inflate',
#  256: 'Ryan',
#  257: 'Gourmet',
#  258: 'drinks',
#  259: '10',
#  260: 'soggy',
#  261: 'sucker',
#  262: 'grilled',
#  263: 'shrimp',
#  264: 'pancake',
#  265: 'postinos',
#  266: 'Highly',
#  267: 'bars',
#  268: 'uploaded',
#  269: 'disappointed',
#  270: 'eel',
#  271: 'Rick',
#  272: 'extremely',
#  273: 'Nicest',
#  274: 'mmmm',
#  275: 'Restaurant',
#  276: 'recently',
#  277: 'plate',
#  278: 'between',
#  279: 'in',
#  280: 'powdered',
#  281: 'likes',
#  282: 'time',
#  283: 'descriptions',
#  284: 'seemed',
#  285: 'including',
#  286: 'suffers',
#  287: 'live',
#  288: 'angry',
#  289: 'boiled',
#  290: 'opinion',
#  291: 'crowd',
#  292: 'giving',
#  293: 'colder',
#  294: 'scallop',
#  295: 'great',
#  296: 'else',
#  297: 'decent',
#  298: 'non-customer',
#  299: 'Hut',
#  300: 'modern',
#  301: 'places',
#  302: 'moz',
#  303: '&',
#  304: 'sharply',
#  305: 'rather',
#  306: 'coziness',
#  307: 'IN',
#  308: 'in-house',
#  309: 'garden',
#  310: 'saving',
#  311: 'Join',
#  312: 's',
#  313: 'recall',
#  314: 'Blah',
#  315: 'winner',
#  316: 'little',
#  317: 'course',
#  318: 'pastas',
#  319: 'devine',
#  320: 'bathroom',
#  321: 'sashimi',
#  322: 'sucked',
#  323: 'brunch',
#  324: 'biscuit',
#  325: 'Hawaiian',
#  326: 'us',
#  327: 'must-stop',
#  328: 'room',
#  329: 'those',
#  330: 'review',
#  331: 'class',
#  332: 'Albondigas',
#  333: 'rudely',
#  334: 'gross',
#  335: '7',
#  336: 'proclaimed',
#  337: 'handed',
#  338: 'Heart',
#  339: 'disgraceful',
#  340: 'Really',
#  341: 'hella',
#  342: 'ambiance',
#  343: 'received',
#  344: 'flavor',
#  345: 'spot',
#  346: '12',
#  347: 'Host',
#  348: 'trippy',
#  349: 'quantity',
#  350: 'on',
#  351: 'Jenni',
#  352: 'gloves.Everything',
#  353: 'EXPERIENCE',
#  354: 'wontons',
#  355: 'Hunan',
#  356: 'allergy',
#  357: 'readers',
#  358: 'Bachi',
#  359: 'he',
#  360: 'plethora',
#  361: 'tell',
#  362: 'THAT',
#  363: 'Pita',
#  364: 'climbing',
#  365: '.',
#  366: 'puree',
#  367: 'curry',
#  368: 'peas',
#  369: 'oh',
#  370: 'sorely',
#  371: 'fry',
#  372: 'plastic',
#  373: 'seal',
#  374: 'brisket',
#  375: 'smoke',
#  376: '30',
#  377: 'Carly',
#  378: 'his',
#  379: 'dining',
#  380: 'customize',
#  381: "'ll",
#  382: 'now',
#  383: 'cramming',
#  384: 'Filet',
#  385: 'Strike',
#  386: 'bunch',
#  387: 'somethat',
#  388: 'officially',
#  389: 'pink',
#  390: 'High-quality',
#  391: 'seasonal',
#  392: 'hip',
#  393: 'nicest',
#  394: 'Things',
#  395: 'edible',
#  396: 'selection',
#  397: 'takeout',
#  398: 'judging',
#  399: 'bellies',
#  400: "n't",
#  401: 'looked',
#  402: 'Stars',
#  403: 'parents',
#  404: 'count',
#  405: 'Indian',
#  406: 'no',
#  407: 'Needless',
#  408: 'croutons',
#  409: 'andddd',
#  410: 'combination',
#  411: 'being',
#  412: 'meat',
#  413: 'club',
#  414: 'Firehouse',
#  415: 'bacon',
#  416: 'mile',
#  417: 'style',
#  418: 'Luke',
#  419: 'ok',
#  420: 'As',
#  421: 'bought',
#  422: 'pancakes',
#  423: 'accountant',
#  424: 'prices',
#  425: 'Tucson',
#  426: 'A',
#  427: 'know',
#  428: 'charming',
#  429: 'occasions',
#  430: 'flavors',
#  431: 'should',
#  432: 'HAPPENED',
#  433: 'tots',
#  434: 'concern',
#  435: 'opportunity',
#  436: 'T.',
#  437: 'sub-par',
#  438: 'excellent',
#  439: 'flat-lined',
#  440: 'Sooooo',
#  441: 'unless',
#  442: 'terrible',
#  443: 'Seat',
#  444: 'wings',
#  445: 'beans',
#  446: 'dressing',
#  447: 'concept',
#  448: 'serivce',
#  449: 'GO',
#  450: 'do',
#  451: 'chip',
#  452: 'buying',
#  453: 'fare',
#  454: 'crêpe',
#  455: 'Chicken',
#  456: 'server',
#  457: 'cheeseburger',
#  458: 'saffron',
#  459: 'Spend',
#  460: 'bodes',
#  461: 'outrageously',
#  462: 'dirty',
#  463: 'just',
#  464: 'Steiners',
#  465: 'bakery',
#  466: 'Anyways',
#  467: 'away',
#  468: 'greedy',
#  469: 'holiday',
#  470: 'salty',
#  471: 'lacked',
#  472: 'more',
#  473: 'email',
#  474: 'Burger',
#  475: 'kept',
#  476: 'before',
#  477: 'wrap',
#  478: 'sides',
#  479: 'huevos',
#  480: 'sense',
#  481: 'shower',
#  482: 'FREEZING',
#  483: 'accomodate',
#  484: 'next',
#  485: 'overcooked',
#  486: 'provided',
#  487: 'back',
#  488: 'crust',
#  489: 'topic',
#  490: 'setting',
#  491: 'suggestions',
#  492: 'lawyers',
#  493: 'excuse',
#  494: 'outside',
#  495: 'beautifully',
#  496: 'beateous',
#  497: 'Pizza',
#  498: 'surprise',
#  499: 'Only',
#  500: 'gristle',
#  501: 'mojitos',
#  502: 'AYCE',
#  503: 'known',
#  504: 'is',
#  505: 'one',
#  506: 'want',
#  507: 'enjoyable',
#  508: 'WAY',
#  509: 'gave',
#  510: 'tribute',
#  511: 'petty',
#  512: 'tastings',
#  513: 'idea',
#  514: 'seasoning',
#  515: 'Ample',
#  516: 'block',
#  517: 'Kind',
#  518: 'attached',
#  519: 'hilarious',
#  520: 'downtown',
#  521: 'myself',
#  522: 'several',
#  523: 'register',
#  524: 'Nothing',
#  525: 'amount',
#  526: 'Disappointed',
#  527: 'since',
#  528: 'without',
#  529: 'forgetting',
#  530: 'Eclectic',
#  531: 'deserves',
#  532: 'batch',
#  533: 'located',
#  534: 'SCREAMS',
#  535: 'meh',
#  536: 'BETTER',
#  537: 'like',
#  538: 'peach',
#  539: 'by',
#  540: 'cart',
#  541: 'forever',
#  542: '6',
#  543: 'fair',
#  544: 'surprised',
#  545: 'two',
#  546: 'glad',
#  547: 'cream',
#  548: 'Chipotle',
#  549: 'old',
#  550: 'besides',
#  551: 'instantly',
#  552: 'with',
#  553: 'expectations',
#  554: 'bread',
#  555: 'Love',
#  556: 'joke',
#  557: 'grandmother',
#  558: 'sad',
#  559: 'salad',
#  560: 'sliced',
#  561: '15',
#  562: '2007',
#  563: 'delight',
#  564: 'folks',
#  565: 'ordering',
#  566: 'paid',
#  567: 'vain',
#  568: 'completely',
#  569: 'desired',
#  570: 'affordable',
#  571: 'driest',
#  572: 'Mirage',
#  573: 'Paying',
#  574: 'send',
#  575: 'fucking',
#  576: 'Edinburgh',
#  577: 'dirt',
#  578: 'these',
#  579: 'legit',
#  580: 'missed',
#  581: 'discount',
#  582: 'pretty',
#  583: 'vinaigrette',
#  584: 'Greek',
#  585: 'Eew',
#  586: 'nothing',
#  587: 'arrives',
#  588: 'prime',
#  589: 'Unfortunately',
#  590: 'mains',
#  591: 'things',
#  592: 'privileged',
#  593: 'funny',
#  594: 'remember',
#  595: 'Wo',
#  596: 'neighborhood',
#  597: 'Subway',
#  598: 'degree',
#  599: 'WASTE',
#  600: 'hoping',
#  601: 'cook',
#  602: 'dont',
#  603: 'highly',
#  604: 'BEST',
#  605: 'Brushfire',
#  606: 'fried',
#  607: 'three',
#  608: 'Plater',
#  609: 'gluten',
#  610: 'Our',
#  611: 'read',
#  612: 'yay',
#  613: 'pricey',
#  614: 'rolled',
#  615: 'really',
#  616: 'year',
#  617: 'hits',
#  618: '11.99',
#  619: 'fun',
#  620: 'LOVED',
#  621: 'plus',
#  622: 'toro',
#  623: 'ice',
#  624: 'soooooo',
#  625: 'TOTAL',
#  626: 'brings',
#  627: 'Mediterranean',
#  628: 'business',
#  629: 'thin',
#  630: 'strawberry',
#  631: 'apparently',
#  632: 'a',
#  633: 'authentic',
#  634: 'nigiri',
#  635: 'wrong',
#  636: 'Yeah',
#  637: 'quick',
#  638: 'Cod',
#  639: 'needed',
#  640: 'fan',
#  641: 'lacking',
#  642: 'enthusiastic',
#  643: 'combo',
#  644: 'final',
#  645: 'honest',
#  646: 'ten',
#  647: 'APPETIZERS',
#  648: 'liking',
#  649: 'immediately',
#  650: 'Smashburger',
#  651: 'unfortunately',
#  652: 'OWNERS',
#  653: 'worst',
#  654: 'Sat',
#  655: 'dates',
#  656: 'weekend',
#  657: 'figured',
#  658: 'bottom',
#  659: 'help',
#  660: 'Sorry',
#  661: 'WILL',
#  662: 'special',
#  663: 'Cartel',
#  664: 'original',
#  665: 'despicable',
#  666: 'containers',
#  667: 'many',
#  668: '40min',
#  669: 'boot',
#  670: 'disgrace',
#  671: 'new',
#  672: 'fries',
#  673: 'waited',
#  674: 'rinse',
#  675: 'summarize',
#  676: 'nut',
#  677: 'rich',
#  678: 'Bellagio',
#  679: 'thinking',
#  680: 'star',
#  681: 'awkward',
#  682: 'never',
#  683: 'people',
#  684: 'couple',
#  685: 'awesome',
#  686: 'bloodiest',
#  687: 'decision',
#  688: 'smells',
#  689: 'Bay',
#  690: 'crab',
#  691: 'dog',
#  692: 'pub',
#  693: 'milk',
#  694: 'as',
#  695: 'expected',
#  696: 'inside',
#  697: 'Ordered',
#  698: 'Up',
#  699: 'loudly',
#  700: 'extraordinary',
#  701: 'rarely',
#  702: 'atrocious',
#  703: 'Omelets',
#  704: 'hole',
#  705: 'greasy',
#  706: 'stupid',
#  707: 'left',
#  708: 'regular',
#  709: 'godfathers',
#  710: 'insanely',
#  711: 'instead',
#  712: 'EVER',
#  713: 'undercooked',
#  714: 'power',
#  715: 'Mellow',
#  716: 'margaritas',
#  717: 'free',
#  718: '...',
#  719: 'full',
#  720: 'poorly',
#  721: 'have',
#  722: 'mayo',
#  723: 'Customer',
#  724: "'s",
#  725: 'Gordon',
#  726: 'Burrittos',
#  727: 'ALL',
#  728: 'deuchebaggery',
#  729: 'truly',
#  730: 'Vegetarian',
#  731: 'potato',
#  732: 'guess',
#  733: 'pleasant',
#  734: 'night',
#  735: 'tiny',
#  736: 'hospitality',
#  737: 'flavorful',
#  738: 'yummy',
#  739: 'perpared',
#  740: 'crisp',
#  741: 'attack',
#  742: 'dinner',
#  743: 'big',
#  744: 'Buldogis',
#  745: 'BACK',
#  746: 'offers',
#  747: 'underwhelming',
#  748: 'human',
#  749: 'beautiful',
#  750: 'WHAT',
#  751: '?',
#  752: 'literally',
#  753: 'beyond',
#  754: 'PERFECT',
#  755: 'lost',
#  756: 'ohhh',
#  757: 'dried',
#  758: 'golden-crispy',
#  759: 'point',
#  760: 'stepped',
#  761: 'held',
#  762: '3',
#  763: 'its',
#  764: 'light',
#  765: 'Perfect',
#  766: 'Con',
#  767: 'get',
#  768: 'HANDS',
#  769: 'Mmmm',
#  770: 'Worse',
#  771: 'vegan/veggie',
#  772: 'Tonight',
#  773: 'salads',
#  774: 'promise',
#  775: 'WAAAAAAyyyyyyyyyy',
#  776: 'non-fancy',
#  777: 'First',
#  778: 'arrived',
#  779: 'rave',
#  780: 'fellow',
#  781: 'donut',
#  782: '1.5lb',
#  783: 'treated',
#  784: 'shops',
#  785: 'flat',
#  786: 'suggest',
#  787: 'tough',
#  788: 'or',
#  789: 'Vegas',
#  790: 'bus',
#  791: 'meals',
#  792: '.....',
#  793: 'Total',
#  794: 'none',
#  795: 'It',
#  796: 'accommodations',
#  797: 'Toast',
#  798: '2',
#  799: 'peanut',
#  800: 'picture',
#  801: 'rate',
#  802: 'Although',
#  803: 'Plus',
#  804: 'Noca',
#  805: 'reviews',
#  806: 'it',
#  807: 'Wonderful',
#  808: 'almost',
#  809: 'boy',
#  810: 'Mushroom',
#  811: 'traditional',
#  812: 'options',
#  813: 'callings',
#  814: 'breaks',
#  815: 'difference',
#  816: 'ridiculous',
#  817: 'Area',
#  818: 'dude',
#  819: 'man',
#  820: 'flop',
#  821: 'coming',
#  822: 'upgrading',
#  823: 'sangria',
#  824: '1',
#  825: 'summary',
#  826: 'heart',
#  827: 'feel',
#  828: 'average',
#  829: 'yum',
#  830: 'shoots',
#  831: 'closed',
#  832: 'hurry',
#  833: 'app',
#  834: 'every',
#  835: 'banana',
#  836: 'duck',
#  837: 'right',
#  838: 'soooo',
#  839: 'box',
#  840: 'refrained',
#  841: '$',
#  842: 'delightful',
#  843: 'lover',
#  844: 'smoothies',
#  845: 'hard',
#  846: 'still',
#  847: 'char',
#  848: 'decided',
#  849: 'guys',
#  850: 'am',
#  851: 'flavored',
#  852: 'Always',
#  853: 'eat',
#  854: 'stood',
#  855: 'profound',
#  856: 'evening',
#  857: 'gratuity',
#  858: 'occasional',
#  859: 'turn',
#  860: 'overhaul',
#  861: 'certainly',
#  862: 'ravoli',
#  863: 'changing',
#  864: 'For',
#  865: 'tragedy',
#  866: 'also',
#  867: 'Friend',
#  868: 'name',
#  869: 'chains',
#  870: 'dollars',
#  871: 'ordered',
#  872: 'greeted',
#  873: 'rushed',
#  874: 'Chinese',
#  875: 'dreamed',
#  876: 'door',
#  877: 'sore',
#  878: 'later',
#  879: 'hardly',
#  880: 'below',
#  881: 'correct',
#  882: 'companions',
#  883: 'hereas',
#  884: 'will',
#  885: 'bug',
#  886: 'Long',
#  887: 'area',
#  888: 'sever',
#  889: 'NONE',
#  890: 'Ironman',
#  891: 'refill',
#  892: 'MUST',
#  893: 'All',
#  894: 'luck',
#  895: 'shocked',
#  896: 'raspberry',
#  897: 'job',
#  898: 'how',
#  899: 'Mango',
#  900: 'elegantly',
#  901: 'yukon',
#  902: 'somewhat',
#  903: 'buffets',
#  904: 'yourself',
#  905: 'Now',
#  906: 'Dos',
#  907: ')',
#  908: 'cakes',
#  909: 'dessert',
#  910: 'vodka',
#  911: 'professional',
#  912: 'honor',
#  913: 'madhouse',
#  914: 'strip',
#  915: 'table',
#  916: 'patty',
#  917: 'further',
#  918: 'silently',
#  919: 'years',
#  920: 'done',
#  921: 'finally',
#  922: 'But',
#  923: 'hot',
#  924: 'salmon',
#  925: 'complete',
#  926: 'satifying',
#  927: 'performed',
#  928: 'everyone',
#  929: 'space',
#  930: 'waiting',
#  931: 'dime',
#  932: 'poisoning',
#  933: 'bathrooms',
#  934: 'cover',
#  935: 'for',
#  936: 'etc',
#  937: 'talking',
#  938: 'waiter',
#  939: 'first',
#  940: 'vegetarian',
#  941: 'wines',
#  942: 'lighter',
#  943: 'fact',
#  944: 'watch',
#  945: 'sexy',
#  946: 'others',
#  947: 'item',
#  948: 'personally',
#  949: 'fuzzy',
#  950: 'editing',
#  951: 'disagree',
#  952: 'and',
#  953: 'Large',
#  954: 'doubt',
#  955: 'Voodoo',
#  956: 'venturing',
#  957: 'Best',
#  958: 'tepid',
#  959: 'use',
#  960: 'cool',
#  961: 'shoe',
#  962: 'acknowledged',
#  963: 'provides',
#  964: 'Be',
#  965: 'section',
#  966: '8',
#  967: 'handmade',
#  968: 'Oh',
#  969: 'needs',
#  970: "ya'all",
#  971: 'bad',
#  972: 'drinking',
#  973: 'summer',
#  974: 'may',
#  975: 'largely',
#  976: 'exactly',
#  977: 'receives',
#  978: 'week',
#  979: 'wanted',
#  980: 'middle',
#  981: 'Then',
#  982: 'cause',
#  983: 'five',
#  984: 'long',
#  985: 'cashew',
#  986: 'obviously',
#  987: 'otherwise',
#  988: 'helpful',
#  989: 'typical',
#  990: 'wish',
#  991: 'incredibly',
#  992: 'anyone',
#  993: 'times',
#  994: 'BITCHES',
#  995: 'place',
#  996: 'The',
#  997: 'boyfriend',
#  998: 'wow',
#  999: 'bill',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
